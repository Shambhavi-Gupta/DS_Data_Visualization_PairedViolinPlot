# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhavi-Gupta/DS_Data_Visualization_PairedVoilinPlot/blob/master/DS_Data_Visualization_PairedVoilinPlots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
p = sns.load_dataset('penguins')

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,data=p[p.sex=='MALE']);

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,data=p[p.sex=='FEMALE']);

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,hue ='sex' ,split=True ,data=p);

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,hue ='sex' ,inner ='quartile' ,split=True ,data=p);

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,hue ='species' ,data=p);

# %%
p['binary_species'] = p.species.apply(lambda x: 0  if x == 'Gentoo' else 1)

# %%
p
# Out:
#     species     island  culmen_length_mm  ...  body_mass_g     sex  binary_species
# 0    Adelie  Torgersen              39.1  ...       3750.0    MALE               1
# 1    Adelie  Torgersen              39.5  ...       3800.0  FEMALE               1
# 2    Adelie  Torgersen              40.3  ...       3250.0  FEMALE               1
# 3    Adelie  Torgersen               NaN  ...          NaN     NaN               1
# 4    Adelie  Torgersen              36.7  ...       3450.0  FEMALE               1
# ..      ...        ...               ...  ...          ...     ...             ...
# 339  Gentoo     Biscoe               NaN  ...          NaN     NaN               0
# 340  Gentoo     Biscoe              46.8  ...       4850.0  FEMALE               0
# 341  Gentoo     Biscoe              50.4  ...       5750.0    MALE               0
# 342  Gentoo     Biscoe              45.2  ...       5200.0  FEMALE               0
# ...

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,hue ='binary_species' ,inner ='quartile' ,split=True ,data=p);

# %%
p['binary_species'] = p.species.apply(lambda x: 'Gentoo'  if x == 'Gentoo' else 'Adelie | Chinstrip' )

# %%
sns.violinplot(x ='island', y ='flipper_length_mm' ,hue ='binary_species' ,inner ='quartile' ,split=True ,data=p);
